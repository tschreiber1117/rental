# %%
class Item:
    def __init__(self, price, rentalincome, laundryroom, storage, misc, tax, insurance, utilities, hoa, lawn_snow, repairs, propmgr, mortgage):
        self.price = price
        self.rentalincome = rentalincome
        self.laundryroom = laundryroom
        self.storage = storage
        self.misc = misc
        self.tax = tax
        self.insurance = insurance
        self.utilities = utilities
        self.hoa = hoa
        self.lawn_snow = lawn_snow
        self.repairs = repairs
        self.propmgr = propertymgr
        self.mortgage = mortgage
        
        
    
    


class Income:
    def __init__(self):
        self.money = []
    def show_item(self):
        print(f'Monthly Income ${self.price} \t| {self.rentalincome} {self.laundryroom} {self.storage} {self.misc}')
    def rentalincome(self): 
        rentalincome = float(input('Enter the rental income '))
        laundryroom = float(input('Enter laundry room income. Enter $0 if not available '))
        storage = float(input('Enter storage room income. Enter $0 if not available '))
        misc = float(input('Enter any additional miscellaneous income. Enter $0 if not available '))
        new_rentalincome = Item(rentalincome, laundryroom, storage, misc)
        self.money.append(new_rentalincome)
        print(f'You added {new_rentalincome} - {new_rentalincome.price} to your monthly income.')
        self.show()
        
        
    def show(self):
        print(self.items)
        print("Here's your current income:")
        print('------------')
        for item in self.money:
            item.show_money()
        print('------------')
        input(f'\nPress any key to continue.')
               
class Expenses:
    def __init__(self):
    
        def expenses(self): 
            tax = float(input('Enter the taxes on property '))
            insurance = float(input('Enter insurance amount. Enter $0 if not available '))
            storage = float(input('Enter utilities amount. Enter $0 if not available '))
            hoa = float(input('Enter HOA amount. Enter $0 if not available '))
            lawn_snow = float(input('Enter lawncare and/or snow removal amount. Enter $0 if not available '))
            repairs = float(input('Enter estimated repairs amount. Enter $0 if not available '))
            propmgr = float(input('Enter Property Manager fee. Enter $0 if not available '))
            mortgage = float(input('Enter mortgage amount. Enter $0 if not available '))
        
class Cashflow:
    def __init__(self):
        
        cashincome = float(input('Enter total amount of Income '))
        cashexpense = float(input('Enter total amount of Expenses '))
    
class CashoncashROI:
    def __init__(self):
        
        downpayment = float(input('Enter total downpayment '))
        closing = float(input('Enter total closing cost fees '))
        rehab = float(input('Enter total rehab cost '))
        
money = Item()
while True:
    choice = input('What would you like to add to your rental property? Income/Expenses/CashFlow/ROI ').lower()
    if choice == 'income':
        money.rentalincome()
        
    elif choice == 'expenses':
        money.expenses()
    
    elif choice == 'cashflow':
        money.cashflow()
        
    elif choice == 'roi':
        money.roi()
    
    else:
        print('Not a valid input.')
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-6-64e521dd9840> in <module>
#      71         rehab = float(input('Enter total rehab cost '))
#      72
# ---> 73 money = Item()
#      74 while True:
#      75     choice = input('What would you like to add to your rental property? Income/Expenses/CashFlow/ROI ').lower()
#
# TypeError: __init__() missing 13 required positional arguments: 'price', 'rentalincome', 'laundryroom', 'storage', 'misc', 'tax', 'insurance', 'utilities', 'hoa', 'lawn_snow', 'repairs', 'propmgr', and 'mortgage'
